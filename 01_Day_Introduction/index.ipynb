# %% [markdown]
# # **Day One of the 30 Days of Python Code Challenge.**

# %% [markdown]
# On the first day of the challenge, I embarked on simple tasks like simply writing code in python.
#
# - I performed simple computations
# - I also checked the data types of various inputs in Python

# %% [markdown]
# ##  Simple Computations

# %%
# addition

3 + 2
# Out:
# 5

# %%
# subtraction 

3 - 2
# Out:
# 1

# %%
# Multiplication 
3*2
# Out:
# 6

# %%
# division 
3/2
# Out:
# 1.5

# %%
# exponential 
3**2
# Out:
# 9

# %%
# modulus (remainder)

3%2
# Out:
# 1

# %%
# floor division - rounding down to the nearest integer no matter what the decimal part is 

print(3//2) 

print(7//2)

print(9//2)
# Out:
# 1
# 3
# 4

# %% [markdown]
# ## Checking Data types

# %%
# integer 

type(10)
# Out:
# int

# %%
# Float - pi

type(3.14)
# Out:
# float

# %%
# complex 

type(1+3j)
# Out:
# complex

# %%
# string 

type("Asabeneh")
# Out:
# str

# %%
# list 

type([1,2,3])
# Out:
# list

# %%
# Dictionary 

type({"name":"Asabeneh"})
# Out:
# dict

# %%
# set

type ({9.8, 3.14, 2.7})
# Out:
# set

# %%
# tuple 

type((9.8, 3.14,2.7))
# Out:
# tuple

# %%
# Boolean 

print(type(3==3))

print(type(3>=3))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ## Observations and conclusion
#
# - Although I have done all of these things, I think it is crucial to revisit the basics every once in a while to cement my knowledge.
# - My biggest take away from today is the difference in syntax between a tuple and a set. I have also been able to create a`Table of Content within` the notebook and it feels ~darn great~ if I do say so myself.
